# %%
from ecallisto_ng.plotting.api import FlareDetection

detector = FlareDetection(model_id="a853ec9b54244b4ab37dce5498597fd3", device="cpu")
# Out:
# ...
# 2024/01/21 16:51:08 WARNING mlflow.pytorch: Stored model version '2.1.2+cu121' does not match installed PyTorch version '2.1.2'

# %%
data, probabilities_per_minute, fig = detector.detect("2024-01-04 00:00:00", "Australia-ASSA_62", window_length="2h")
fig.show()
# Out:
# Detecting flares from 2024-01-04 00:00:00 to 2024-01-04 02:00:00 on Australia-ASSA_62
# ...
# /var/folders/l3/rl43cxg95q9dgp35dpn4hlgw0000gn/T/ipykernel_23901/1396333414.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
data
# Out:
#                          14.995  15.308  15.683  16.058  16.433  16.808  \
# 2024-01-04 00:00:00.043     161     160     177     173     156     150
# 2024-01-04 00:00:00.293     160     158     166     169     155     155
# 2024-01-04 00:00:00.543     159     157     160     163     152     152
# 2024-01-04 00:00:00.793     160     158     162     161     148     149
# 2024-01-04 00:00:01.043     160     156     160     170     152     150
# ...                         ...     ...     ...     ...     ...     ...
# 2024-01-04 01:59:58.735     154     135     137     137     136     136
# 2024-01-04 01:59:58.985     154     135     136     137     136     136
# 2024-01-04 01:59:59.235     154     134     136     137     137     136
# 2024-01-04 01:59:59.485     155     135     136     137     136     137
# 2024-01-04 01:59:59.735     154     134     136     137     136     137
#
#                          17.183  17.558  17.933  18.308  ...  83.558  83.933  \
# ...

# %%
probabilities_per_minute
# Out:
# {0: 0.00016619591042399406,
#  1: 0.0007628404418937862,
#  2: 0.0005185470611953255,
#  3: 0.0004181604858786159,
#  4: 0.0006170802491396899,
#  5: 0.0005241918064105752,
#  6: 0.0007192896609922173,
#  7: 0.0006420911865916423,
#  8: 0.0005816030217020954,
#  9: 0.0005845236095410655,
#  10: 0.0005427438152930171,
#  11: 0.000517533758435699,
#  12: 0.0004779248626374073,
#  13: 0.00044527663325360275,
#  14: 0.0004240456642188898,
#  15: 0.0004322739166279158,
#  16: 0.00034887528537789575,
#  17: 0.00034822276985930025,
#  18: 0.00034303364953605826,
#  19: 0.00025636647428655123,
#  20: 0.00026233140741472504,
#  21: 0.0001404141534142885,
#  22: 0.00013527387416919132,
#  23: 0.000138376312421921,
#  24: 0.00011584290064092784,
#  25: 0.00011105945254712424,
#  26: 0.000579524137219778,
#  27: 0.0005805733705832002,
#  28: 0.0005821829725997911,
#  29: 0.0005777760982406714,
#  30: 0.0005821108518527277,
#  31: 0.0005757831250472616,
#  32: 0.0005745893481919969,
# ...
